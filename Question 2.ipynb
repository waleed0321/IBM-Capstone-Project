# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plot
import numpy as np
import seaborn as sns

# %%
df=pd.read_csv('final_project')
df.head()
# Out:
#    Unnamed: 0  unique_key             created_date closed_date agency  \
# 0           0    46145045  2020-05-07T01:58:58.000         NaN    DPR
# 1           1    46144582  2020-05-07T01:58:52.000         NaN   NYPD
# 2           2    46141137  2020-05-07T01:55:35.000         NaN    DHS
# 3           3    46140689  2020-05-07T01:55:20.000         NaN   NYPD
# 4           4    46144448  2020-05-07T01:54:05.000         NaN   NYPD
#
#                           agency_name              complaint_type  \
# 0  Department of Parks and Recreation            New Tree Request
# 1     New York City Police Department     Noise - Street/Sidewalk
# 2     Department of Homeless Services  Homeless Person Assistance
# 3     New York City Police Department         Noise - Residential
# 4     New York City Police Department         Noise - Residential
#
#          descriptor               location_type  incident_zip  ...  \
# 0   For One Address                      Street       10312.0  ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 42 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Unnamed: 0                      1000 non-null   int64
#  1   unique_key                      1000 non-null   int64
#  2   created_date                    1000 non-null   object
#  3   closed_date                     642 non-null    object
#  4   agency                          1000 non-null   object
#  5   agency_name                     1000 non-null   object
#  6   complaint_type                  1000 non-null   object
#  7   descriptor                      965 non-null    object
#  8   location_type                   849 non-null    object
#  9   incident_zip                    992 non-null    float64
#  10  incident_address                987 non-null    object
#  11  street_name                     987 non-null    object
# ...

# %%
df['borough'].value_counts()
# Out:
# BROOKLYN         304
# BRONX            232
# QUEENS           222
# MANHATTAN        215
# STATEN ISLAND     26
# Unspecified        1
# Name: borough, dtype: int64

# %%
top_complaint = df[df['complaint_type'] == 'HEAT/HOT WATER'].reset_index(drop = True)
top_complaint.head()
# Out:
#    Unnamed: 0  unique_key             created_date closed_date agency  \
# 0         183    46143743  2020-05-06T23:58:48.000         NaN    HPD
# 1         212    46143749  2020-05-06T23:47:08.000         NaN    HPD
# 2         218    46145356  2020-05-06T23:44:58.000         NaN    HPD
# 3         239    46146207  2020-05-06T23:34:22.000         NaN    HPD
# 4         264    46145336  2020-05-06T23:30:29.000         NaN    HPD
#
#                                          agency_name  complaint_type  \
# 0  Department of Housing Preservation and Develop...  HEAT/HOT WATER
# 1  Department of Housing Preservation and Develop...  HEAT/HOT WATER
# 2  Department of Housing Preservation and Develop...  HEAT/HOT WATER
# 3  Department of Housing Preservation and Develop...  HEAT/HOT WATER
# 4  Department of Housing Preservation and Develop...  HEAT/HOT WATER
#
#         descriptor         location_type  incident_zip  ... vehicle_type  \
# ...

# %%
top=top_complaint['borough'].value_counts()
top.sort_values(ascending=True, inplace=True)

# %%
top.plot(kind='barh',figsize=(12,12))

# %%
# finding streets about top complaints
top_complaint_s=top_complaint['street_name'].value_counts()
top_complaint_s.sort_values(ascending=True, inplace=True)

# %%
top_complaint_s.plot(kind='barh',figsize=(12,12))
